# %% [markdown]
# <a href="https://colab.research.google.com/github/nusco/colab-tutorial/blob/main/The_20_Minutes_Colab_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The 20 Minutes Colab Tutorial
#
# Welcome! You're looking at a Colab notebook. This text is inside a *cell*. Cells are formatted with the [Markdown](https://www.markdownguide.org/basic-syntax/) formatting syntax, so they contain images, links… the works.
#
# Go ahead: double-click on this cell to see its source text. Feel free to edit it if you wish. Don't worry, you won't be able to save changes back to the original notebook. (But you can make your own copy if you wish!)
#
# Once you're done, press `Shift+Return` to run the cell. In the case of a text cell like this one, "running" it means that the text gets formatted.

# %% [markdown]
# The main feature of Colab is that cells can also contain code. Python code is recognized by default. Try running the cell below. (It's still `Shift+Return`, or you can click on the little arrow that appears on the left side of the cell when you hover over it.)

# %%
for i in range(3):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!

# %% [markdown]
# Did it take a few seconds for the code to run? That's because the first time you run a code cell, Colab connects to a machine hosted by Google. Here in
